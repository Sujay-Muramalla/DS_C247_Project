# %%
print ("helo")

# %%
print ("helloworld")

# %%
import sys
print (sys.executable)
# Out:
# /Users/sujaymuramalla/Documents/Projects/DS_C247_Project/.venv/bin/python

# %%
print ("hello world")
# Out:
# hello world

# %%
print ("hello world")
# Out:
# hello world

# %%
print ("hello world")
# Out:
# Running cells with '.venv (Python 3.14.0)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Lenovo/OneDrive/Backup_23102024/d_drive/PERSONAL/Career/Projects/DS_C247_Project/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
print ("hello world")
# Out:
# Running cells with '.venv (Python 3.14.0)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Lenovo/OneDrive/Backup_23102024/d_drive/PERSONAL/Career/Projects/DS_C247_Project/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
print ("hello world")
# Out:
# hello world
